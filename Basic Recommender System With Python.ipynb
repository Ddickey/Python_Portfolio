# %% [markdown]
# ##Basic Recommender System With Python
#
# This code will suggest an item taht is most similar to another item.
#
# Data set: Movies
#
# Not a robust recommendation system

# %%
import numpy as np
import pandas as pd

# %%
column_names = ['user_id','item_id','rating','timestamp']

# %%
df = pd.read_csv('u.data', sep='\t', names = column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 4 columns):
# user_id      100003 non-null int64
# item_id      100003 non-null int64
# rating       100003 non-null int64
# timestamp    100003 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
df.describe()
# Out:
#              user_id        item_id         rating     timestamp
# count  100003.000000  100003.000000  100003.000000  1.000030e+05
# mean      462.470876     425.520914       3.529864  8.835288e+08
# std       266.622454     330.797791       1.125704  5.343791e+06
# min         0.000000       1.000000       1.000000  8.747247e+08
# 25%       254.000000     175.000000       3.000000  8.794487e+08
# 50%       447.000000     322.000000       4.000000  8.828269e+08
# 75%       682.000000     631.000000       4.000000  8.882600e+08
# max       943.000000    1682.000000       5.000000  8.932866e+08

# %% [markdown]
# Notice how there are no movie titles in the u.data data set
#
# Lets read another CSV and join it to the u.data by a common key (much like SQL)

# %%
movie_titles = pd.read_csv("Movie_Id_Titles")

# %% [markdown]
# movie_titles = pd.read_csv("Movie_Id_Titles")

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
movie_titles.describe()
# Out:
#            item_id
# count  1682.000000
# mean    841.500000
# std     485.695893
# min       1.000000
# 25%     421.250000
# 50%     841.500000
# 75%    1261.750000
# max    1682.000000

# %%
movie_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 2 columns):
# item_id    1682 non-null int64
# title      1682 non-null object
# dtypes: int64(1), object(1)
# memory usage: 26.4+ KB

# %%
df = pd.merge(df,movie_titles,on='item_id')  ##this is like joining on item_id in SQL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100003 entries, 0 to 100002
# Data columns (total 5 columns):
# user_id      100003 non-null int64
# item_id      100003 non-null int64
# rating       100003 non-null int64
# timestamp    100003 non-null int64
# title        100003 non-null object
# dtypes: int64(4), object(1)
# memory usage: 4.6+ MB

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
df.describe()
# Out:
#              user_id        item_id         rating     timestamp
# count  100003.000000  100003.000000  100003.000000  1.000030e+05
# mean      462.470876     425.520914       3.529864  8.835288e+08
# std       266.622454     330.797791       1.125704  5.343791e+06
# min         0.000000       1.000000       1.000000  8.747247e+08
# 25%       254.000000     175.000000       3.000000  8.794487e+08
# 50%       447.000000     322.000000       4.000000  8.828269e+08
# 75%       682.000000     631.000000       4.000000  8.882600e+08
# max       943.000000    1682.000000       5.000000  8.932866e+08

# %% [markdown]
# Now we have title and the data in the same data set

# %% [markdown]
# # EDA
#
# time for exploratory data analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title')['rating'].median().sort_values(ascending=False)
# Out:
# title
# Shall We Dance? (1996)                                         5.0
# Faust (1994)                                                   5.0
# Star Wars (1977)                                               5.0
# Entertaining Angels: The Dorothy Day Story (1996)              5.0
# Godfather, The (1972)                                          5.0
# Pather Panchali (1955)                                         5.0
# Usual Suspects, The (1995)                                     5.0
# Letter From Death Row, A (1998)                                5.0
# Shawshank Redemption, The (1994)                               5.0
# Prefontaine (1997)                                             5.0
# Paradise Lost: The Child Murders at Robin Hood Hills (1996)    5.0
# Someone Else's America (1995)                                  5.0
# Casablanca (1942)                                              5.0
# Titanic (1997)                                                 5.0
# ...

# %%
df.groupby('title')['rating'].mode().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-2940896ef255> in <module>()
# ----> 1 df.groupby('title')['rating'].mode().sort_values(ascending=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
df.groupby('title')['rating'].mean()
# Out:
# title
# 'Til There Was You (1997)                                   2.333333
# 1-900 (1994)                                                2.600000
# 101 Dalmatians (1996)                                       2.908257
# 12 Angry Men (1957)                                         4.344000
# 187 (1997)                                                  3.024390
# 2 Days in the Valley (1996)                                 3.225806
# 20,000 Leagues Under the Sea (1954)                         3.500000
# 2001: A Space Odyssey (1968)                                3.969112
# 3 Ninjas: High Noon At Mega Mountain (1998)                 1.000000
# 39 Steps, The (1935)                                        4.050847
# 8 1/2 (1963)                                                3.815789
# 8 Heads in a Duffel Bag (1997)                              3.250000
# 8 Seconds (1994)                                            3.750000
# ...

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False)
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)                 5.000000
# Prefontaine (1997)                                        5.000000
# Santa with Muscles (1996)                                 5.000000
# Star Kid (1997)                                           5.000000
# Someone Else's America (1995)                             5.000000
# Entertaining Angels: The Dorothy Day Story (1996)         5.000000
# Saint of Fort Washington, The (1993)                      5.000000
# Great Day in Harlem, A (1994)                             5.000000
# They Made Me a Criminal (1939)                            5.000000
# Aiqing wansui (1994)                                      5.000000
# Pather Panchali (1955)                                    4.625000
# Anna (1996)                                               4.500000
# Everest (1998)                                            4.500000
# Maya Lin: A Strong Clear Vision (1994)                    4.500000
# ...

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
avg_rating = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
avg_rating.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
avg_rating['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())

# %%
avg_rating.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
plt.figure(figsize=(15,6))
rating['num of ratings'].hist(bins=70)

# %%
plt.figure(figsize=(15,6))
rating['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y='num of ratings',data=rating,alpha=0.5)
# Out:
# C:\Users\Jerimiah\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Jerimiah\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# EDA is done, now we build the recommender system

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
avg_rating.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# Star Wars (1977)               4.359589             584
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
liarliar_user_ratings = moviemat['Liar Liar (1997)']
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
correlated_with_starwars = moviemat.corrwith(starwars_user_ratings)
correlated_with_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# C:\Users\Jerimiah\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3159: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Jerimiah\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3093: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
print(correlated_with_starwars)
# Out:
# title
# 'Til There Was You (1997)                                   0.872872
# 1-900 (1994)                                               -0.645497
# 101 Dalmatians (1996)                                       0.211132
# 12 Angry Men (1957)                                         0.184289
# 187 (1997)                                                  0.027398
# 2 Days in the Valley (1996)                                 0.066654
# 20,000 Leagues Under the Sea (1954)                         0.289768
# 2001: A Space Odyssey (1968)                                0.230884
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.106453
# 8 1/2 (1963)                                               -0.142977
# 8 Heads in a Duffel Bag (1997)                             -0.577350
# 8 Seconds (1994)                                           -0.755929
# ...

# %%
print(correlated_with_liarliar)
# Out:
# title
# 'Til There Was You (1997)                                   0.118913
# 1-900 (1994)                                                     NaN
# 101 Dalmatians (1996)                                       0.469765
# 12 Angry Men (1957)                                         0.066272
# 187 (1997)                                                  0.175145
# 2 Days in the Valley (1996)                                 0.040739
# 20,000 Leagues Under the Sea (1954)                        -0.027932
# 2001: A Space Odyssey (1968)                               -0.057864
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.400918
# 8 1/2 (1963)                                                0.178064
# 8 Heads in a Duffel Bag (1997)                                   NaN
# 8 Seconds (1994)                                                 NaN
# ...

# %%
corr_starwars = pd.DataFrame(correlated_with_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Man of the Year (1995)                                      1.0
# Hollow Reed (1996)                                          1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Good Man in Africa, A (1994)                                1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars = corr_starwars.join(rating['num of ratings'])
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %%
corr_liarliar = pd.DataFrame(correlated_with_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(rating['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False)
# Out:
#                                                     Correlation  \
# title
# Liar Liar (1997)                                       1.000000
# Batman Forever (1995)                                  0.516968
# Mask, The (1994)                                       0.484650
# Down Periscope (1996)                                  0.472681
# Con Air (1997)                                         0.469828
# Pretty Woman (1990)                                    0.469790
# 101 Dalmatians (1996)                                  0.469765
# Michael (1996)                                         0.442022
# Waterworld (1995)                                      0.438405
# Indiana Jones and the Last Crusade (1989)              0.414427
# Young Guns (1988)                                      0.410988
# Top Gun (1986)                                         0.405720
# G.I. Jane (1997)                                       0.397931
# ...

# %% [markdown]
# Maybe not the best recommender system every built but it is a good start.
